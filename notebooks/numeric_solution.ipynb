# %%
import moran_process
from moran_process import PopulationGraph
from moran_process.numeric import fixation_prob, absorb_time

# %%
# g = PopulationGraph.complete_graph(n_nodes=20)
# g = PopulationGraph.mammalian_lung_graph(branching_factor=4, depth=2)
g = PopulationGraph.avian_graph(n_rods=4, rod_length=4)
# g = PopulationGraph.fish_graph(n_rods=2, rod_length=1)
g.draw()

# %%
core = g.to_simulation_struct()
r = 1.0

fp = fixation_prob(core, r)
at = absorb_time(core, r)

print(fp)
print(at)
